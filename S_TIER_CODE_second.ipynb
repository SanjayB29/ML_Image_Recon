# %%
# import os
# import csv
# import cv2
# from tkinter import filedialog
# import tkinter as tk

# class ImageLabelingApp:
#     def __init__(self, window, window_title):
#         self.window = window
#         self.window.title(window_title)
#         self.images_folder = ""

#         self.label_frame = tk.LabelFrame(self.window, text="Labeling")
#         self.label_frame.pack(padx=20, pady=20)

#         self.label_var = tk.StringVar()
#         self.label_var.set("")

#         self.image_label = tk.Label(self.label_frame)
#         self.image_label.pack()

#         self.sleeping_button = tk.Button(self.label_frame, text="Sleeping", command=lambda: self.label_image("sleeping"))
#         self.sleeping_button.pack(side=tk.LEFT, padx=10)

#         self.awake_button = tk.Button(self.label_frame, text="Awake", command=lambda: self.label_image("awake"))
#         self.awake_button.pack(side=tk.LEFT, padx=10)

#         self.skip_button = tk.Button(self.label_frame, text="Skip", command=self.skip_image)
#         self.skip_button.pack(side=tk.LEFT, padx=10)

#         self.images_list = []
#         self.current_image_index = 0
#         self.labels = []

#         self.load_images()
#         self.load_labels()

#         self.window.mainloop()

#     def load_images(self):
#         self.images_folder = filedialog.askdirectory(title="Select Images Folder")
#         if self.images_folder:
#             self.images_list = [filename for filename in os.listdir(self.images_folder) if filename.lower().endswith(('.jpg', '.jpeg', '.png'))]
#             self.show_image()

#     def load_labels(self):
#         csv_file = os.path.join(self.images_folder, "labels.csv")
#         if os.path.exists(csv_file):
#             with open(csv_file, "r") as file:
#                 reader = csv.reader(file)
#                 self.labels = [row for row in reader]

#     def show_image(self):
#         if self.images_list and self.current_image_index < len(self.images_list):
#             image_path = os.path.join(self.images_folder, self.images_list[self.current_image_index])
#             image = cv2.imread(image_path)
#             image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#             image = cv2.resize(image, (400, 300))
#             image = Image.fromarray(image)
#             photo = ImageTk.PhotoImage(image=image)
#             self.image_label.config(image=photo)
#             self.image_label.image = photo

#     def label_image(self, label):
#         if self.images_list and self.current_image_index < len(self.images_list):
#             self.labels.append([self.images_list[self.current_image_index], label])
#             self.current_image_index += 1
#             self.show_image()
#             self.save_labels()

#     def skip_image(self):
#         if self.images_list:
#             self.current_image_index += 1
#             self.show_image()

#     def save_labels(self):
#         csv_file = os.path.join(self.images_folder, "labels.csv")
#         with open(csv_file, "w", newline="") as file:
#             writer = csv.writer(file)
#             writer.writerows(self.labels)

# if __name__ == "__main__":
#     root = tk.Tk()
#     app = ImageLabelingApp(root, "Image Labeling App")

# %%
import cv2
import tkinter as tk
from tkinter.simpledialog import askstring
from tkinter import filedialog
from PIL import Image, ImageTk
import os

class WebcamApp:
    def __init__(self, window, window_title):
        self.window = window
        self.window.title(window_title)

        self.video_capture = cv2.VideoCapture(0)
        self.current_frame = None
        self.image_path = ""

        self.video_frame = tk.Label(self.window)
        self.video_frame.grid(row=0, column=0, columnspan=2)

        self.capture_button = tk.Button(self.window, text="Capture", width=10, command=self.capture_image)
        self.capture_button.grid(row=1, column=0, padx=10, pady=5)

        self.browse_button = tk.Button(self.window, text="Browse", width=10, command=self.browse_directory)
        self.browse_button.grid(row=1, column=1, padx=10, pady=5)

        self.exit_button = tk.Button(self.window, text="Exit", width=10, command=self.exit_app)
        self.exit_button.grid(row=2, column=0, columnspan=2, pady=5)

        self.update()
        self.window.protocol("WM_DELETE_WINDOW", self.exit_app)  # Bind close button to exit_app
        self.window.mainloop()

    def update(self):
        ret, frame = self.video_capture.read()
        if ret:
            self.current_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            self.photo = ImageTk.PhotoImage(image=Image.fromarray(self.current_frame))
            self.video_frame.config(image=self.photo)
        self.window.after(10, self.update)

    def capture_image(self):
        if self.current_frame is not None and self.image_path:
            image_name = askstring("Image Name", "Enter a name for the image:")
            if image_name:
                image_filename = os.path.join(self.image_path, f"{image_name}.jpg")
                cv2.imwrite(image_filename, cv2.cvtColor(self.current_frame, cv2.COLOR_RGB2BGR))
                print(f"Photo captured and saved as {image_filename}")

    def browse_directory(self):
        self.image_path = filedialog.askdirectory()
        print(f"Image storage directory set to: {self.image_path}")

    def exit_app(self):
        self.video_capture.release()
        self.window.destroy()

if __name__ == "__main__":
    root = tk.Tk()
    app = WebcamApp(root, "Webcam Capture App")
# Out:
# Image storage directory set to: D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\a.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\b.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\c.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\aa.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\bb.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\cc.jpg

# %%
import os
import csv
import cv2
import numpy as np
import h5py
from tkinter import filedialog, messagebox
import tkinter as tk
from PIL import Image, ImageTk

class ImageLabelingApp:
    def __init__(self, window, window_title):
        self.window = window
        self.window.title(window_title)
        self.images_folder = ""
        self.images_list = []
        self.current_image_index = 0
        self.labels = {}
        self.image_arrays = []

        self.label_frame = tk.LabelFrame(self.window, text="Labeling")
        self.label_frame.pack(padx=20, pady=20)

        self.label_var = tk.StringVar()
        self.label_var.set("")

        self.image_label = tk.Label(self.label_frame)
        self.image_label.pack()

        self.sleeping_button = tk.Button(self.label_frame, text="Sleeping", command=lambda: self.label_image("sleeping"))
        self.sleeping_button.pack(side=tk.LEFT, padx=10)

        self.awake_button = tk.Button(self.label_frame, text="Awake", command=lambda: self.label_image("awake"))
        self.awake_button.pack(side=tk.LEFT, padx=10)

        self.skip_button = tk.Button(self.label_frame, text="Skip", command=self.skip_image)
        self.skip_button.pack(side=tk.LEFT, padx=10)

        self.load_images()
        self.load_labels()

        self.window.mainloop()

    def load_images(self):
        self.images_folder = filedialog.askdirectory(title="Select Images Folder")
        if self.images_folder:
            self.images_list = [filename for filename in os.listdir(self.images_folder) if filename.lower().endswith(('.jpg', '.jpeg', '.png'))]
            self.show_image()

    def load_labels(self):
        csv_file = os.path.join(self.images_folder, "labels.csv")
        if os.path.exists(csv_file):
            with open(csv_file, "r") as file:
                reader = csv.reader(file)
                self.labels = {row[0]: row[1] for row in reader}

    def show_image(self):
        if self.images_list and 0 <= self.current_image_index < len(self.images_list):
            image_path = os.path.join(self.images_folder, self.images_list[self.current_image_index])
            image = cv2.imread(image_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            self.image_arrays.append(image)
            image = cv2.resize(image, (400, 300))
            image = Image.fromarray(image)
            photo = ImageTk.PhotoImage(image=image)
            self.image_label.config(image=photo)
            self.image_label.image = photo

    def label_image(self, label):
        if self.images_list and 0 <= self.current_image_index < len(self.images_list):
            filename = self.images_list[self.current_image_index]
            self.labels[filename] = label
            self.current_image_index += 1
            self.show_image()
            self.save_labels()

    def skip_image(self):
        if self.images_list:
            self.current_image_index += 1
            self.show_image()

    def save_labels(self):
        csv_file = os.path.join(self.images_folder, "labels.csv")
        with open(csv_file, "w", newline="") as file:
            writer = csv.writer(file)
            for filename, label in self.labels.items():
                writer.writerow([filename, label])

        if self.current_image_index >= len(self.images_list):
            self.convert_to_grayscale_and_flatten()

    def convert_to_grayscale_and_flatten(self):
        grayscale_data = []

        for filename, label in self.labels.items():
            image_path = os.path.join(self.images_folder, filename)
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
            flattened_image = image.flatten()
            
            # Convert label to a numeric value
            label_numeric = 1 if label == "sleeping" else 0
            
            # Append label_numeric to the flattened_image array
            flattened_image = np.append(flattened_image, label_numeric)
            
            grayscale_data.append(flattened_image)

        grayscale_hdf5_file = os.path.join(self.images_folder, "grayscale_data.h5")
        with h5py.File(grayscale_hdf5_file, 'w') as hdf5_file:
            hdf5_file.create_dataset('data', data=grayscale_data)

        messagebox.showinfo("Conversion Done", "Grayscale and flattening conversion is complete!")
        self.window.destroy()

if __name__ == "__main__":
    root = tk.Tk()
    app = ImageLabelingApp(root, "Image Labeling and Data Conversion App")

# %%
import h5py
import pandas as pd

# Load the HDF5 file
hdf5_file_path = "grayscale_data.h5"  # Update with the actual path
hdf5_file = h5py.File(hdf5_file_path, 'r')

# Load the data from the HDF5 file
data = hdf5_file['data'][:]

# Close the HDF5 file
hdf5_file.close()

# Convert the data into a pandas DataFrame
# Assuming the last column contains labels
df_columns = [f'pixel_{i}' for i in range(data.shape[1] - 1)] + ['label']
df = pd.DataFrame(data, columns=df_columns)

# Show the DataFrame
print(df)
# Out:
#    pixel_0  pixel_1  pixel_2  pixel_3  pixel_4  pixel_5  pixel_6  pixel_7  \
# 0        4        4        4        3        2        2        2        2
# 1        6        6        5        5        5        4        4        5
#
#    pixel_8  pixel_9  ...  pixel_307191  pixel_307192  pixel_307193  \
# 0        3        4  ...            29            28            28
# 1        6        4  ...            23            24            25
#
#    pixel_307194  pixel_307195  pixel_307196  pixel_307197  pixel_307198  \
# 0            27            25            24            22            22
# 1            27            28            28            29            31
#
#    pixel_307199  label
# 0            22      1
# 1            31      0
#
# [2 rows x 307201 columns]

# %%
df.shape
# Out:
# (2, 307201)

# %%
X = df.iloc[:, :-1].values
y = df['label'].values

# Show X and y
print("X:")
print(X)
print("\ny:")
print(y)
# Out:
# X:
# [[ 4  4  4 ... 22 22 22]
#  [ 6  6  5 ... 29 31 31]]
#
# y:
# [1 0]

# %%
X=X/255
X
# Out:
# array([[0.01568627, 0.01568627, 0.01568627, ..., 0.08627451, 0.08627451,
#         0.08627451],
#        [0.02352941, 0.02352941, 0.01960784, ..., 0.11372549, 0.12156863,
#         0.12156863]])

# %%
import cv2
import tkinter as tk
from tkinter.simpledialog import askstring
from tkinter import filedialog, messagebox
from PIL import Image, ImageTk
import os
import csv
import numpy as np
import h5py
import random

class WebcamLabelingApp:
    def __init__(self, window, window_title):
        self.window = window
        self.window.title(window_title)
        self.capture_mode = None  # 'sleeping' or 'awake'
        self.image_storage_folder = ""
        self.labels = {}

        self.label_frame = tk.LabelFrame(self.window, text="Labeling")
        self.label_frame.pack(padx=20, pady=20)

        self.label_var = tk.StringVar()
        self.label_var.set("")

        self.image_label = tk.Label(self.label_frame)
        self.image_label.pack()

        self.sleeping_button = tk.Button(self.label_frame, text="Sleeping", command=self.set_sleeping_mode)
        self.sleeping_button.pack(side=tk.LEFT, padx=10)

        self.awake_button = tk.Button(self.label_frame, text="Awake", command=self.set_awake_mode)
        self.awake_button.pack(side=tk.LEFT, padx=10)

        self.start_capture_button = tk.Button(self.label_frame, text="Start Capture", command=self.start_capture)
        self.start_capture_button.pack(side=tk.LEFT, padx=10)

        self.load_labels()

        self.window.mainloop()

    def load_labels(self):
        self.image_storage_folder = filedialog.askdirectory(title="Select Image Storage Folder")
        if self.image_storage_folder:
            csv_file = os.path.join(self.image_storage_folder, "labels.csv")
            if os.path.exists(csv_file):
                with open(csv_file, "r") as file:
                    reader = csv.reader(file)
                    self.labels = {row[0]: row[1] for row in reader}

    def set_sleeping_mode(self):
        self.capture_mode = 'sleeping'
        self.label_var.set("Sleeping")

    def set_awake_mode(self):
        self.capture_mode = 'awake'
        self.label_var.set("Awake")

    def start_capture(self):
        if not self.capture_mode:
            messagebox.showerror("Capture Mode Not Set", "Please select a capture mode (Sleeping or Awake).")
            return

        if not self.image_storage_folder:
            messagebox.showerror("Image Storage Folder Not Selected", "Please select an image storage folder.")
            return

        for _ in range(10):
            self.capture_image()

        self.save_labels()
        self.convert_to_grayscale_and_flatten()

    def capture_image(self):
        cap = cv2.VideoCapture(0)
        ret, frame = cap.read()
        cap.release()

        if ret:
            image_name = self.generate_unique_filename()
            image_filename = os.path.join(self.image_storage_folder, f"{image_name}.jpg")
            cv2.imwrite(image_filename, frame)
            print(f"Photo captured and saved as {image_filename}")
            self.labels[image_name] = self.capture_mode

    def generate_unique_filename(self):
        while True:
            image_name = f"image_{random.randint(1, 100000)}"
            if image_name not in self.labels:
                return image_name

    def save_labels(self):
        csv_file = os.path.join(self.image_storage_folder, "labels.csv")
        with open(csv_file, "w", newline="") as file:
            writer = csv.writer(file)
            for filename, label in self.labels.items():
                writer.writerow([filename, label])

    def convert_to_grayscale_and_flatten(self):
        grayscale_data = []

        for filename, label in self.labels.items():
            image_path = os.path.join(self.image_storage_folder, f"{filename}.jpg")
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
            flattened_image = image.flatten()
            
            # Convert label to a numeric value
            label_numeric = 1 if label == "sleeping" else 0
            
            # Append label_numeric to the flattened_image array
            flattened_image = np.append(flattened_image, label_numeric)
            
            grayscale_data.append(flattened_image)

        grayscale_hdf5_file = os.path.join(self.image_storage_folder, "grayscale_data.h5")
        with h5py.File(grayscale_hdf5_file, 'w') as hdf5_file:
            hdf5_file.create_dataset('data', data=grayscale_data)

        messagebox.showinfo("Conversion Done", "Grayscale and flattening conversion is complete!")
        self.window.destroy()

if __name__ == "__main__":
    root = tk.Tk()
    app = WebcamLabelingApp(root, "Webcam Labeling and Data Conversion App")
# Out:
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_32735.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_12314.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_77580.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_42810.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_77576.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_34638.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_3408.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_74065.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_3637.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_34328.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_23364.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_77643.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_65249.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\image_5215.jpg
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\sanja\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\sanja\AppData\Local\Temp\ipykernel_884\3138506800.py", line 69, in start_capture
#     self.capture_image()
#   File "C:\Users\sanja\AppData\Local\Temp\ipykernel_884\3138506800.py", line 75, in capture_image
#     cap = cv2.VideoCapture(0)
#           ^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 124
#     122 if __name__ == "__main__":
#     123     root = tk.Tk()
# --> 124     app = WebcamLabelingApp(root, "Webcam Labeling and Data Conversion App")
#
# Cell In[7], line 40, in WebcamLabelingApp.__init__(self, window, window_title)
#      36 self.start_capture_button.pack(side=tk.LEFT, padx=10)
#      38 self.load_labels()
# ---> 40 self.window.mainloop()
#
# File c:\Users\sanja\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py:1485, in Misc.mainloop(self, n)
#    1483 def mainloop(self, n=0):
#    1484     """Call the mainloop of Tk."""
# -> 1485     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
import cv2
import tkinter as tk
from tkinter.simpledialog import askstring
from tkinter import filedialog
from PIL import Image, ImageTk
import os
import random
import string

class WebcamApp:
    def __init__(self, window, window_title):
        self.window = window
        self.window.title(window_title)

        self.video_capture = cv2.VideoCapture(0)
        self.current_frame = None
        self.image_path = ""

        self.video_frame = tk.Label(self.window)
        self.video_frame.grid(row=0, column=0, columnspan=2)

        self.capture_button = tk.Button(self.window, text="Capture", width=10, command=self.capture_image)
        self.capture_button.grid(row=1, column=0, padx=10, pady=5)

        self.browse_button = tk.Button(self.window, text="Browse", width=10, command=self.browse_directory)
        self.browse_button.grid(row=1, column=1, padx=10, pady=5)

        self.exit_button = tk.Button(self.window, text="Exit", width=10, command=self.exit_app)
        self.exit_button.grid(row=2, column=0, columnspan=2, pady=5)

        self.update()
        self.window.protocol("WM_DELETE_WINDOW", self.exit_app)  # Bind close button to exit_app
        self.window.mainloop()

    def update(self):
        ret, frame = self.video_capture.read()
        if ret:
            self.current_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            self.photo = ImageTk.PhotoImage(image=Image.fromarray(self.current_frame))
            self.video_frame.config(image=self.photo)
        self.window.after(10, self.update)

    def capture_image(self):
        if self.current_frame is not None and self.image_path:
            for _ in range(50):  # Capture 50 images
                image_name = self.generate_random_name()
                image_filename = os.path.join(self.image_path, f"{image_name}.jpg")
                cv2.imwrite(image_filename, cv2.cvtColor(self.current_frame, cv2.COLOR_RGB2BGR))
                print(f"Photo captured and saved as {image_filename}")

    def browse_directory(self):
        self.image_path = filedialog.askdirectory()
        print(f"Image storage directory set to: {self.image_path}")

    def exit_app(self):
        self.video_capture.release()
        self.window.destroy()

    def generate_random_name(self, length=10):
        letters = string.ascii_letters
        return ''.join(random.choice(letters) for _ in range(length))

if __name__ == "__main__":
    root = tk.Tk()
    app = WebcamApp(root, "Webcam Capture App")
# Out:
# Image storage directory set to: D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\PPplIKONKW.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\HFGcCRboke.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\yDWZBZjGxU.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\wyfSEIJFTY.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\TcFiYOfFzZ.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\kKVIzPusfn.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\vLXKpmFPeX.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\GxXpCutOts.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\KxPPRCJVQA.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\zidlrSLcfc.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\xDheIdqdAe.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\juUOGQykPV.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\SvRgWjLKwl.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\EEulBIxiCp.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\fNFFiAwYaS.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\oAaaRsmxln.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\yclnSaIgYX.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\GEVkXOUgRk.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\KimsNNhMWH.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\HNllzxcUfe.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\XNrJOzgrBy.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\hXxqWXZPlJ.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\GbJWtjVgwH.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\CjOpwboyVj.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\lFcGCeqFHX.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\EoZCcXZxYW.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\KqdwFVREoq.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\BpknkztaWN.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\qcGOnJioWN.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\KCboTosHfP.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\HVlwXLGjKq.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\lYVBIxMpwk.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\OuDKBUfACc.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\CgZpfPhtrn.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\XXyBScXTmv.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\vjEAwnShEi.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\OeeITmYsJT.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\oxcwDDSCUa.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\iMTmJYGqGk.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\cJvcfiNVMN.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\UUXMkyHWsg.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\CGeNwsglvV.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\XimRxeMrDn.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\aLnaYwPSCu.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\KZHnPCqUhS.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\TwEuASDzbJ.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\hBwqswxyiB.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\NYmzYTKqNo.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\cYEjNFfdeP.jpg
# Photo captured and saved as D:/Amrita/Sem_5/Machine Learning/ProjectIR/pics_data\aCFuvbcHti.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 65
#      63 if __name__ == "__main__":
#      64     root = tk.Tk()
# ---> 65     app = WebcamApp(root, "Webcam Capture App")
#
# Cell In[1], line 33, in WebcamApp.__init__(self, window, window_title)
#      31 self.update()
#      32 self.window.protocol("WM_DELETE_WINDOW", self.exit_app)  # Bind close button to exit_app
# ---> 33 self.window.mainloop()
#
# File c:\Users\sanja\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py:1485, in Misc.mainloop(self, n)
#    1483 def mainloop(self, n=0):
#    1484     """Call the mainloop of Tk."""
# -> 1485     self.tk.mainloop(n)
#
# File c:\Users\sanja\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py:1943, in CallWrapper.__call__(self, *args)
#    1940     self.subst = subst
#    1941     self.widget = widget
# -> 1943 def __call__(self, *args):
#    1944     """Apply first function SUBST to arguments, than FUNC."""
#    1945     try:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
